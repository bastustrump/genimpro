# %% [markdown]
# # Comparison of sonic events (recorder)

# %%
# %cd /Users/bastus/Desktop/Forschungsprojekt/genimpro
# %pylab inline
# %run importwrapper.py
# Out:
# /Users/bastus/Desktop/Forschungsprojekt/genimpro
# Populating the interactive namespace from numpy and matplotlib

# %%
genimpro.recordings.getRecordingDetails(133)
# Out:
# [133,
#  u'recorder',
#  u'2015-08-20 10:00',
#  2,
#  [[u'Martin Weigert',
#    u'recorder',
#    u'2/6c79816a-01ff-4742-8462-3ebba84b7eb8.aiff',
#    75,
#    133],
#   [u'Caroline Hausen',
#    u'recorder',
#    u'2/b264c1d3-1737-4df1-99c3-b62e27dfcbf7.aiff',
#    76,
#    133]]]

# %%
analysedTrack = genimpro.recordings.getRecordingDetails(133)[4][0]
genimpro.analyseTrack(analysedTrack,updateAll=1)
# Out:
#     Martin Weigert (recorder): 2/6c79816a-01ff-4742-8462-3ebba84b7eb8.aiff
#     512 onsets found
# Updated 512 sonicevents for track 75
# Added 56 sequences for track 75
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/scipy/ndimage/interpolation.py:532: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-3f7921b4c0c8> in <module>()
#       1 analysedTrack = genimpro.recordings.getRecordingDetails(133)[4][0]
# ----> 2 genimpro.analyseTrack(analysedTrack,updateAll=1)
#
# /Users/bastus/Desktop/Forschungsprojekt/genimpro/genimpro.pyc in analyseTrack(track, updateAll)
# ...

# %%
se = genimpro.recordings.getSoniceventsForTrack(analysedTrack)
audio = genimpro.recordings.getAudioForTrack(analysedTrack)

# %% [markdown]
# ## Beispielklänge mit Feature-Diagramm

# %% [markdown]
# **Beispiel 1:** Rimclick (p)

# %%
plotFeaturesWithPlayer(se[31:32],audio,showStatistics=1)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %% [markdown]
# **Beispiel 2:** Rimclick (p)

# %%
plotFeaturesWithPlayer(se[13:14],audio,showStatistics=1)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %% [markdown]
# **Beispiel 3:** Snareschlag dumpf (pp)

# %%
plotFeaturesWithPlayer(se[5:6],audio,showStatistics=1)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %% [markdown]
# **Beispiel 4:** Snareschlag (p, höher)

# %%
plotFeaturesWithPlayer(se[7:8],audio,showStatistics=1)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %% [markdown]
# **Beispiel 4:** Snareschlag (mf)

# %%
plotFeaturesWithPlayer(se[8:9],audio,showStatistics=1)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %% [markdown]
# **Beispiel 5:** Wirbel

# %%
plotFeaturesWithPlayer(se[200:201],audio,showStatistics=1)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>

# %% [markdown]
# **Beispiel 6:** Wirbel (crescendo, descrescendo)

# %%
plotFeaturesWithPlayer(se[171:182],audio,showStatistics=0)
# Out:
#     <body>
#     <audio controls="controls" style="width:600px" >
#       <source controls src="..." type="audio/mpeg" />
#       Your browser does not support the audio element.
#     </audio>
#     </body>
